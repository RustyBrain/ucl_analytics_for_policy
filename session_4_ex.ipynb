# %%
library(dplyr)
library(tidyverse)
# Out:
# Warning message:
# “As of rlang 0.4.0, dplyr must be at least version 0.8.0.
# ✖ dplyr 0.7.8 is too old for rlang 0.4.2.
# ℹ Please update dplyr with `install.packages("dplyr")`.”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ ggplot2 3.1.0     ✔ readr   1.3.1
# ✔ tibble  2.0.1     ✔ purrr   0.3.0
# ✔ tidyr   0.8.2     ✔ stringr 1.4.0
# ✔ ggplot2 3.1.0     ✔ forcats 0.3.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
df <- read.csv('lab_data/mysterydata.csv')

# %%
df
# Out:
#      pclass survived name                                              sex
# 1    1      1        Allen, Miss. Elisabeth Walton                     female
# 2    1      1        Allison, Master. Hudson Trevor                    male
# 3    1      0        Allison, Miss. Helen Loraine                      female
# 4    1      0        Allison, Mr. Hudson Joshua Creighton              male
# 5    1      0        Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   female
# 6    1      1        Anderson, Mr. Harry                               male
# 7    1      1        Andrews, Miss. Kornelia Theodosia                 female
# 8    1      0        Andrews, Mr. Thomas Jr                            male
# 9    1      1        Appleton, Mrs. Edward Dale (Charlotte Lamson)     female
# 10   1      0        Artagaveytia, Mr. Ramon                           male
# 11   1      0        Astor, Col. John Jacob                            male
# ...

# %%
summary(df)
# Out:
#      pclass         survived                                   name
#  Min.   :1.000   Min.   :0.000   Connolly, Miss. Kate            :   2
#  1st Qu.:2.000   1st Qu.:0.000   Kelly, Mr. James                :   2
#  Median :3.000   Median :0.000   Abbing, Mr. Anthony             :   1
#  Mean   :2.295   Mean   :0.382   Abbott, Master. Eugene Joseph   :   1
#  3rd Qu.:3.000   3rd Qu.:1.000   Abbott, Mr. Rossmore Edward     :   1
#  Max.   :3.000   Max.   :1.000   Abbott, Mrs. Stanton (Rosa Hunt):   1
#                                  (Other)                         :1301
#      sex           age               fare
#  female:466   Min.   : 0.1667   Min.   :  0.000
#  male  :843   1st Qu.:21.0000   1st Qu.:  7.896
#               Median :28.0000   Median : 14.454
#               Mean   :29.8811   Mean   : 33.295
#               3rd Qu.:39.0000   3rd Qu.: 31.275
#               Max.   :80.0000   Max.   :512.329
#               NA's   :263       NA's   :1

# %%
df_missing <- df[!complete.cases(df), ]

# %%
df_clean <- df[complete.cases(df), ]

# %%
df[complete.cases(df), ]
# Out:
#      pclass survived name
# 1    1      1        Allen, Miss. Elisabeth Walton
# 2    1      1        Allison, Master. Hudson Trevor
# 3    1      0        Allison, Miss. Helen Loraine
# 4    1      0        Allison, Mr. Hudson Joshua Creighton
# 5    1      0        Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6    1      1        Anderson, Mr. Harry
# 7    1      1        Andrews, Miss. Kornelia Theodosia
# 8    1      0        Andrews, Mr. Thomas Jr
# 9    1      1        Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 10   1      0        Artagaveytia, Mr. Ramon
# 11   1      0        Astor, Col. John Jacob
# 12   1      1        Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 13   1      1        Aubart, Mme. Leontine Pauline
# 14   1      1        Barber, Miss. Ellen "Nellie"
# 15   1      1        Barkworth, Mr. Algernon Henry Wilson
# 17   1      0        Baxter, Mr. Quigg Edmond
# 18   1      1        Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# ...

# %%
head(df_missing)
# Out:
#    pclass survived name
# 16 1      0        Baumann, Mr. John D
# 38 1      1        Bradley, Mr. George ("George Arthur Brayton")
# 41 1      0        Brewe, Dr. Arthur Jackson
# 47 1      0        Cairns, Mr. Alexander
# 60 1      1        Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genevieve Fosdick)
# 70 1      1        Chibnall, Mrs. (Edith Martha Bowerman)
#    sex    age fare
# 16 male   NA  25.9250
# 38 male   NA  26.5500
# 41 male   NA  39.6000
# 47 male   NA  31.0000
# 60 female NA  27.7208
# 70 female NA  55.0000

# %%
head(df_clean)
# Out:
#   pclass survived name                                            sex
# 1 1      1        Allen, Miss. Elisabeth Walton                   female
# 2 1      1        Allison, Master. Hudson Trevor                  male
# 3 1      0        Allison, Miss. Helen Loraine                    female
# 4 1      0        Allison, Mr. Hudson Joshua Creighton            male
# 5 1      0        Allison, Mrs. Hudson J C (Bessie Waldo Daniels) female
# 6 1      1        Anderson, Mr. Harry                             male
#   age     fare
# 1 29.0000 211.3375
# 2  0.9167 151.5500
# 3  2.0000 151.5500
# 4 30.0000 151.5500
# 5 25.0000 151.5500
# 6 48.0000  26.5500

# %%
pass_grouped <- df_clean %>% group_by(sex, pclass)

# %%
pass_grouped %>% summarise(n = n())
# Out:
#   sex    pclass n
# 1 female 1      133
# 2 female 2      103
# 3 female 3      152
# 4 male   1      151
# 5 male   2      158
# 6 male   3      348

# %%
under_10 <- subset(df_clean, age < 10)

# %%
under_10
# Out:
#      pclass survived name                                     sex    age
# 2    1      1        Allison, Master. Hudson Trevor           male   0.9167
# 3    1      0        Allison, Miss. Helen Loraine             female 2.0000
# 95   1      1        Dodge, Master. Washington                male   4.0000
# 274  1      1        Spedden, Master. Robert Douglas          male   6.0000
# 340  2      1        Becker, Master. Richard F                male   1.0000
# 341  2      1        Becker, Miss. Marion Louise              female 4.0000
# 360  2      1        Caldwell, Master. Alden Gates            male   0.8333
# 378  2      1        Collyer, Miss. Marjorie "Lottie"         female 8.0000
# 386  2      1        Davies, Master. John Morgan Jr           male   8.0000
# 399  2      1        Drew, Master. Marshall Brines            male   8.0000
# 428  2      1        Hamalainen, Master. Viljo                male   0.6667
# ...

# %%
!install.packages('dplyr')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘BH’, ‘plogr’
